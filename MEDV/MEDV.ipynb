# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/drive/MyDrive/ML Dataset/housing.csv')
df
# Out:
#         RM  LSTAT  PTRATIO      MEDV
# 0    6.575   4.98     15.3  504000.0
# 1    6.421   9.14     17.8  453600.0
# 2    7.185   4.03     17.8  728700.0
# 3    6.998   2.94     18.7  701400.0
# 4    7.147   5.33     18.7  760200.0
# ..     ...    ...      ...       ...
# 484  6.593   9.67     21.0  470400.0
# 485  6.120   9.08     21.0  432600.0
# 486  6.976   5.64     21.0  501900.0
# 487  6.794   6.48     21.0  462000.0
# 488  6.030   7.88     21.0  249900.0
#
# [489 rows x 4 columns]

# %%
df.shape
# Out:
# (489, 4)

# %%
df.columns
# Out:
# Index(['RM', 'LSTAT', 'PTRATIO', 'MEDV'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489 entries, 0 to 488
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   RM       489 non-null    float64
#  1   LSTAT    489 non-null    float64
#  2   PTRATIO  489 non-null    float64
#  3   MEDV     489 non-null    float64
# dtypes: float64(4)
# memory usage: 15.4 KB

# %%
df.columns=[col.strip() for col in df.columns]
df.dropna(inplace=True)
df.reset_index(drop=True,inplace=True)
df
# Out:
#         RM  LSTAT  PTRATIO      MEDV
# 0    6.575   4.98     15.3  504000.0
# 1    6.421   9.14     17.8  453600.0
# 2    7.185   4.03     17.8  728700.0
# 3    6.998   2.94     18.7  701400.0
# 4    7.147   5.33     18.7  760200.0
# ..     ...    ...      ...       ...
# 484  6.593   9.67     21.0  470400.0
# 485  6.120   9.08     21.0  432600.0
# 486  6.976   5.64     21.0  501900.0
# 487  6.794   6.48     21.0  462000.0
# 488  6.030   7.88     21.0  249900.0
#
# [489 rows x 4 columns]

# %%
df.shape
df
# Out:
#         RM  LSTAT  PTRATIO      MEDV
# 0    6.575   4.98     15.3  504000.0
# 1    6.421   9.14     17.8  453600.0
# 2    7.185   4.03     17.8  728700.0
# 3    6.998   2.94     18.7  701400.0
# 4    7.147   5.33     18.7  760200.0
# ..     ...    ...      ...       ...
# 484  6.593   9.67     21.0  470400.0
# 485  6.120   9.08     21.0  432600.0
# 486  6.976   5.64     21.0  501900.0
# 487  6.794   6.48     21.0  462000.0
# 488  6.030   7.88     21.0  249900.0
#
# [489 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
y=df["MEDV"]
x=df.drop(["MEDV"],axis='columns')
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4)

# %% [markdown]
# Training is started.

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [markdown]
# It used to predict numerical data.
# It check the the performance of the model

# %%
Model=LinearRegression()
Model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=Model.predict(x_test)

print(f"R2 Score = {metrics.r2_score(y_test,y_pred)}")

print(f"Mean Absolute = {metrics.mean_absolute_error(y_test,y_pred)}")

print(f"Mean Squared Error = {metrics.mean_squared_error(y_test,y_pred)}")

print(f"Root Mean Squared Error = {np.sqrt(metrics.mean_squared_error(y_test,y_pred))}")
# Out:
# R2 Score = 0.7223562819988764
# Mean Absolute = 64931.63305899252
# Mean Squared Error = 7480706672.167513
# Root Mean Squared Error = 86491.07856980113

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_pred,y_test,color="blue",marker='o',alpha=0.7,label='Predictions')
plt.plot([min(y_pred),max(y_pred)],[min(y_pred),max(y_pred)],color='red',linestyle='-',linewidth=2,label='Perfect Fit')
plt.xlabel("Actual MEDV")
plt.ylabel("Predicted MEDV")
plt.title("Linear Regression:Predicted MEDV vs Actual MEDV")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(range(len(y_test)),y_test,color="blue")
plt.scatter(range(len(y_pred)),y_pred,color="red")
plt.xlabel("Actual MEDV")
plt.ylabel("Predicted MEDV")
plt.title("Linear Regression:Predicted MEDV vs Actual MEDV")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
